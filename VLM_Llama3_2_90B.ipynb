# %% [markdown]
# <a href="https://colab.research.google.com/github/aritrasen87/MultiModalModels/blob/main/VLM_Llama3_2_90B.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
! pip install together --q
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 69.7/69.7 kB 2.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.5/4.5 MB 62.1 MB/s eta 0:00:00

# %%
import os
from google.colab import userdata
os.environ['TOGETHER_API_KEY'] = userdata.get('TOGETHER_KEY')

# %%
import requests
from PIL import Image
url = "https://upload.wikimedia.org/wikipedia/commons/thumb/3/3a/LLama.jpg/444px-LLama.jpg?20050123205659"
image = Image.open(requests.get(url, stream=True).raw)
image
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=444x600>

# %%
import os
from together import Together
client = Together()
response = client.chat.completions.create(
  model="meta-llama/Llama-3.2-90B-Vision-Instruct-Turbo",
  messages=[
    {
      "role": "user",
      "content": [
        {"type": "text", "text": "What sort of animal is in this picture? What is its usual diet? What area is the animal native to? And isn’t there some AI model that’s related to the image?"},
        {
          "type": "image_url",
          "image_url": {
            "url": "https://upload.wikimedia.org/wikipedia/commons/thumb/3/3a/LLama.jpg/444px-LLama.jpg?20050123205659",
          },
        },
      ],
    }
  ],
  max_tokens=300,
)
print(response.choices[0].message.content)
# Out:
# The animal in the picture is a llama. Llamas are native to South America, specifically the Andean region that includes present-day Peru, Bolivia, Ecuador, and Chile. They were domesticated by the Incas around 6,000 years ago for their wool, meat, and as pack animals.
#
# Llamas are herbivores and their usual diet consists of grasses, plants, and shrubs. They have a unique digestive system that allows them to break down cellulose in plant cell walls, making them well-suited to their native habitat.
#
# As for the AI model, you might be thinking of LLaMA (Large Language Model Application), which is an open-source language model developed by Meta AI. It's not directly related to the image of the llama, but rather shares a similar name. LLaMA is designed to generate human-like text and has been used in various applications such as chatbots, language translation, and text summarization.
